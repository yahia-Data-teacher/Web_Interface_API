# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Web_Interface_API/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlalchemy as sqa
sqa.__version__
# Out:
# '1.4.44'

# %%
engine = sqa.create_engine('postgresql://riktpxik:0wuBX91ltuyPuzy6WxtOjHZL6pARMPUQ@rosie.db.elephantsql.com/riktpxik',echo=True)
engine
# Out:
# Engine(postgresql://riktpxik:***@rosie.db.elephantsql.com/riktpxik)

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
class Room(Base):
    __tablename__ = 'rooms'
    __table_args__ = {'extend_existing': True}
    
    room_id = sqa.Column(sqa.Integer, primary_key = True)
    floor = sqa.Column(sqa.Integer)
    square_footage = sqa.Column(sqa.Integer)
    occupant = sqa.Column(sqa.String)
    rent = sqa.Column(sqa.Float)
    lease_end_date = sqa.Column(sqa.Date)

    def __repr__(self):
        return "Room(room_id = {}, floor = {}, square_footage = {}, occupant = {}, rent = {}, lease_end_date = {})".format(
            self.room_id,
            self.floor,
            self.square_footage,
            self.occupant,
            self.rent,
            self.lease_end_date)

# %%
Room.__table__
# Out:
# Table('rooms', MetaData(), Column('room_id', Integer(), table=<rooms>, primary_key=True, nullable=False), Column('floor', Integer(), table=<rooms>), Column('square_footage', Integer(), table=<rooms>), Column('occupant', String(), table=<rooms>), Column('rent', Float(), table=<rooms>), Column('lease_end_date', Date(), table=<rooms>), schema=None)

# %%
Base.metadata.create_all(engine)
# Out:
# 2022-12-14 11:39:11,208 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-12-14 11:39:11,209 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-12-14 11:39:11,680 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-12-14 11:39:11,682 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-12-14 11:39:12,147 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-12-14 11:39:12,148 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-12-14 11:39:12,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-14 11:39:12,619 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-12-14 11:39:12,620 INFO sqlalchemy.engine.Engine [generated in 0.00088s] {'name': 'rooms'}
# 2022-12-14 11:39:13,086 INFO sqlalchemy.engine.Engine
# CREATE TABLE rooms (
# 	room_id SERIAL NOT NULL,
# 	floor INTEGER,
# 	square_footage INTEGER,
# 	occupant VARCHAR,
# ...

# %%
from sqlalchemy.orm import Session,sessionmaker
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()
session.new
# Out:
# IdentitySet([])

# %%
session.rollback
# Out:
# <bound method Session.rollback of <sqlalchemy.orm.session.Session object at 0x000001F66BCA1450>>

# %%
from faker import Faker
from random import uniform
from random import randint
faker = Faker()

# %%
for i in range(0,50):
    name = faker.first_name() + " " + faker.last_name()
    price = "{0:.2f}".format(uniform(300, 1500))
    room1 = Room(floor = randint(1, 12), square_footage = randint(400, 1500), occupant = name, rent = price, lease_end_date = faker.date())
    session.rollback()
    session.add(room1)
    session.new
    session.commit()
# Out:
# 2022-12-14 11:39:14,144 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-14 11:39:14,148 INFO sqlalchemy.engine.Engine INSERT INTO rooms (floor, square_footage, occupant, rent, lease_end_date) VALUES (%(floor)s, %(square_footage)s, %(occupant)s, %(rent)s, %(lease_end_date)s) RETURNING rooms.room_id
# 2022-12-14 11:39:14,149 INFO sqlalchemy.engine.Engine [generated in 0.00092s] {'floor': 7, 'square_footage': 1210, 'occupant': 'Joshua Wagner', 'rent': '810.23', 'lease_end_date': '2018-04-16'}
# 2022-12-14 11:39:14,617 INFO sqlalchemy.engine.Engine COMMIT
# 2022-12-14 11:39:14,855 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-14 11:39:14,856 INFO sqlalchemy.engine.Engine INSERT INTO rooms (floor, square_footage, occupant, rent, lease_end_date) VALUES (%(floor)s, %(square_footage)s, %(occupant)s, %(rent)s, %(lease_end_date)s) RETURNING rooms.room_id
# ...

# %%
class Student(Base):
    """"""
    __tablename__ = 'student'
    
    id = sqa.Column(sqa.Integer, primary_key = True)
    username = sqa.Column(sqa.String)
    firstname = sqa.Column(sqa.String)
    lastname = sqa.Column(sqa.String)
    university = sqa.Column(sqa.String)
    
    # ----------------------------------
    
    def __init__(self, username, firstname, lastname, university):
        """"""
        self.username = username
        self.firstname = firstname
        self.lastname = lastname
        self.university = university

# %%
from sqlalchemy.ext.declarative import declarative_base
Base.metadata.create_all(engine)
# Out:
# 2022-12-13 12:23:10,370 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2022-12-13 12:23:10,372 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-12-13 12:23:10,796 INFO sqlalchemy.engine.Engine select current_schema()
# 2022-12-13 12:23:10,796 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-12-13 12:23:11,220 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2022-12-13 12:23:11,221 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-12-13 12:23:11,645 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-13 12:23:11,647 INFO sqlalchemy.engine.Engine select relname from pg_class c join pg_namespace n on n.oid=c.relnamespace where pg_catalog.pg_table_is_visible(c.oid) and relname=%(name)s
# 2022-12-13 12:23:11,648 INFO sqlalchemy.engine.Engine [generated in 0.00093s] {'name': 'rooms'}
# ...

# %%
# create a Session
Session = sessionmaker(bind=engine)
session = Session()

# %%
# Create objects  
user = Student("james","James","Boogie","MIT")
session.add(user)

# %%
user = Student("lara","Lara","Miami","UU")
session.add(user)

# %%
user = Student("eric","Eric","York","Stanford")
session.add(user)

# %%
# commit the record the database
session.commit()
# Out:
# 2022-12-13 12:23:24,170 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-12-13 12:23:24,173 INFO sqlalchemy.engine.Engine INSERT INTO student (username, firstname, lastname, university) VALUES (%(username)s, %(firstname)s, %(lastname)s, %(university)s) RETURNING student.id
# 2022-12-13 12:23:24,175 INFO sqlalchemy.engine.Engine [generated in 0.00191s] ({'username': 'james', 'firstname': 'James', 'lastname': 'Boogie', 'university': 'MIT'}, {'username': 'lara', 'firstname': 'Lara', 'lastname': 'Miami', 'university': 'UU'}, {'username': 'eric', 'firstname': 'Eric', 'lastname': 'York', 'university': 'Stanford'})
# 2022-12-13 12:23:24,599 INFO sqlalchemy.engine.Engine COMMIT

# %%
session.rollback()

# %%
query="select * FROM {};".format('student')
engine.execute(query)
# Out:
# 2022-12-14 11:44:51,838 INFO sqlalchemy.engine.Engine select * FROM student;
# 2022-12-14 11:44:51,840 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
query="select * FROM student WHERE id = 1"
a=engine.execute(query)
# Out:
# 2022-12-14 11:46:59,682 INFO sqlalchemy.engine.Engine select * FROM student WHERE id = 1
# 2022-12-14 11:46:59,683 INFO sqlalchemy.engine.Engine [raw sql] {}

# %%
for i in a:
    print(f"{i.id},{i.username}")
# Out:
# 1,james
