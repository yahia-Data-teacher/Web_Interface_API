# %% [markdown]
# <a href="https://colab.research.google.com/github/yahia-kplr/Web_Interface_API/blob/main/.ipynb_checkpoints/step%201-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
